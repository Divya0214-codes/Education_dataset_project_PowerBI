# %%
import pandas as pd
import numpy as np

# %%
# read file
df = pd.read_csv('/content/archive (33).zip')

# %%
df.head()
# Out:
#    gender  age  parental_education_level  family_income  daily_study_hours  \
# 0  Female   15                         2        45000.0                2.9
# 1    Male   19                         2        15000.0                2.8
# 2  Female   20                         5        55000.0                4.0
# 3  Female   16                         5        65000.0                4.6
# 4    Male   20                         4        35000.0                4.3
#
#    attendance_rate  sleep_hours  stress_level  motivation_score  \
# 0            0.916          8.3           6.0                16
# 1            0.760          6.8           5.0                58
# 2            0.894          8.2           6.0                51
# 3            0.888          6.2           6.0                49
# 4            0.923          7.3           4.0                62
#
#    private_tutoring  internet_quality  math_score  reading_score  \
# ...

# %%
df.tail()
# Out:
#         gender  age  parental_education_level  family_income  \
# 199995    Male   18                         7        85000.0
# 199996  Female   17                         4        65000.0
# 199997    Male   18                         4        75000.0
# 199998    Male   21                         3        30000.0
# 199999    Male   20                         2        35000.0
#
#         daily_study_hours  attendance_rate  sleep_hours  stress_level  \
# 199995                7.7            1.000          7.5           7.0
# 199996                3.9            0.891          7.2           7.0
# 199997                3.2            0.859          7.6           4.0
# 199998                4.1            0.950          7.9           5.0
# 199999                2.9            0.745          6.7           6.0
#
#         motivation_score  private_tutoring  internet_quality  math_score  \
# 199995                51              True                 4         100
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   gender                    200000 non-null  object
#  1   age                       200000 non-null  int64
#  2   parental_education_level  200000 non-null  int64
#  3   family_income             195975 non-null  float64
#  4   daily_study_hours         200000 non-null  float64
#  5   attendance_rate           200000 non-null  float64
#  6   sleep_hours               195887 non-null  float64
#  7   stress_level              196087 non-null  float64
#  8   motivation_score          200000 non-null  int64
#  9   private_tutoring          200000 non-null  bool
#  10  internet_quality          200000 non-null  int64
#  11  math_score                200000 non-null  int64
#  12  reading_score             200000 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  age  parental_education_level  family_income  \
# count  200000.000000             200000.000000  195975.000000
# mean       18.150560                  3.692610   51446.026279
# std         1.648916                  1.611864   36070.995180
# min        15.000000                  1.000000   15000.000000
# 25%        17.000000                  2.000000   25000.000000
# 50%        18.000000                  4.000000   40000.000000
# 75%        19.000000                  5.000000   65000.000000
# max        22.000000                  7.000000  400000.000000
#
#        daily_study_hours  attendance_rate    sleep_hours   stress_level  \
# count      200000.000000    200000.000000  195887.000000  196087.000000
# mean            3.752547         0.894103       7.706800       5.097166
# std             0.831978         0.059612       0.930568       1.457824
# min             2.300000         0.585000       4.000000       1.000000
# ...

# %%
df.shape
# Out:
# (200000, 15)

# %%
df.isnull().sum()
# Out:
# gender                         0
# age                            0
# parental_education_level       0
# family_income               4025
# daily_study_hours              0
# attendance_rate                0
# sleep_hours                 4113
# stress_level                3913
# motivation_score               0
# private_tutoring               0
# internet_quality               0
# math_score                     0
# reading_score                  0
# writing_score                  0
# pass_fail                      0
# dtype: int64

# %%
df['family_income'].fillna(df['family_income'].mean(),inplace= True)
# Out:
# /tmp/ipykernel_1018/2685970568.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['family_income'].fillna(df['family_income'].mean(),inplace= True)

# %%
print(int(df['family_income'].mean()))
# Out:
# 51446

# %%
df['sleep_hours']=df['sleep_hours'].fillna(df['sleep_hours'].mode()[0])

# %%
print(df['sleep_hours'].mode())
# Out:
# 0    7.7
# Name: sleep_hours, dtype: float64

# %%
df['stress_level'] = df['stress_level'].fillna(df['stress_level'].mode()[0])

# %%
print(df['stress_level'].mode())
# Out:
# 0    5.0
# Name: stress_level, dtype: float64

# %%
df.isnull().sum()
# Out:
# gender                      0
# age                         0
# parental_education_level    0
# family_income               0
# daily_study_hours           0
# attendance_rate             0
# sleep_hours                 0
# stress_level                0
# motivation_score            0
# private_tutoring            0
# internet_quality            0
# math_score                  0
# reading_score               0
# writing_score               0
# pass_fail                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    gender  age  parental_education_level  family_income  daily_study_hours  \
# 0  Female   15                         2        45000.0                2.9
# 1    Male   19                         2        15000.0                2.8
# 2  Female   20                         5        55000.0                4.0
# 3  Female   16                         5        65000.0                4.6
# 4    Male   20                         4        35000.0                4.3
#
#    attendance_rate  sleep_hours  stress_level  motivation_score  \
# 0            0.916          8.3           6.0                16
# 1            0.760          6.8           5.0                58
# 2            0.894          8.2           6.0                51
# 3            0.888          6.2           6.0                49
# 4            0.923          7.3           4.0                62
#
#    private_tutoring  internet_quality  math_score  reading_score  \
# ...

# %%
# float  convert to int
print("max:",df['stress_level'].max())
print("min:",df['stress_level'].min())
# Out:
# max: 10.0
# min: 1.0

# %%
# float convert to int
print("max:",df['family_income'].max())
print("min:",df['family_income'].min())
# Out:
# max: 400000.0
# min: 15000.0

# %%
# float convert to int
print("max:",df['sleep_hours'].max())
print("min:",df['sleep_hours'].min())
# Out:
# max: 11.0
# min: 4.0

# %%
#float convert to int
print("max:",df['daily_study_hours'].max())
print("min:",df['daily_study_hours'].min())
# Out:
# max: 8.0
# min: 2.3

# %%
# float to percentage
print("max:",df['attendance_rate'].max())
print("min:",df['attendance_rate'].min())
# Out:
# max: 1.0
# min: 0.585

# %%
# int value
print("max:",df['reading_score'].max())
print("min:",df['reading_score'].min())
# Out:
# max: 100
# min: 0

# %%
# int value
print("max:",df['writing_score'].max())
print("min:",df['writing_score'].min())
# Out:
# max: 100
# min: 0

# %%
# int value
print("max:",df['math_score'].max())
print("min:",df['math_score'].min())
# Out:
# max: 100
# min: 0

# %%
# int
print("max:",df['motivation_score'].max())
print("min:",df['motivation_score'].min())
# Out:
# max: 100
# min: 10

# %%
# int
print("max:",df['age'].max())
print("min:",df['age'].min())
# Out:
# max: 22
# min: 15

# %%
# int
print("max:",df['parental_education_level'].max())
print("min:",df['parental_education_level'].min())
# Out:
# max: 7
# min: 1

# %%
# float value convert to interger value
df['stress_level'] = df['stress_level'].astype(int)
df['daily_study_hours'] = df['daily_study_hours'].astype(int)
df['sleep_hours'] = df['sleep_hours'].astype(int)
df['family_income'] = df['family_income'].astype(int)
# attendance rate convert to percentage
df['attendance_rate'] = df['attendance_rate']*100

# %%
df
# Out:
#         gender  age  parental_education_level  family_income  \
# 0       Female   15                         2          45000
# 1         Male   19                         2          15000
# 2       Female   20                         5          55000
# 3       Female   16                         5          65000
# 4         Male   20                         4          35000
# ...        ...  ...                       ...            ...
# 199995    Male   18                         7          85000
# 199996  Female   17                         4          65000
# 199997    Male   18                         4          75000
# 199998    Male   21                         3          30000
# 199999    Male   20                         2          35000
#
#         daily_study_hours  attendance_rate  sleep_hours  stress_level  \
# 0                       2             91.6            8             6
# 1                       2             76.0            6             5
# ...

# %%
df = df.rename(columns={'attendance_rate':'attendance_rate%'})

# %%
df
# Out:
#         gender  age  parental_education_level  family_income  \
# 0       Female   15                         2          45000
# 1         Male   19                         2          15000
# 2       Female   20                         5          55000
# 3       Female   16                         5          65000
# 4         Male   20                         4          35000
# ...        ...  ...                       ...            ...
# 199995    Male   18                         7          85000
# 199996  Female   17                         4          65000
# 199997    Male   18                         4          75000
# 199998    Male   21                         3          30000
# 199999    Male   20                         2          35000
#
#         daily_study_hours  attendance_rate%  sleep_hours  stress_level  \
# 0                       2              91.6            8             6
# 1                       2              76.0            6             5
# ...

# %%
print(df['gender'].unique())
# Out:
# ['Female' 'Male']

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    104075
# Male       95925
# Name: count, dtype: int64

# %%
df.groupby('gender')['attendance_rate%'].value_counts()
# Out:
# gender  attendance_rate%
# Female  100.0               4949
#         88.7                 707
#         87.5                 696
#         90.9                 693
#         90.7                 692
#                             ...
# Male    66.5                   1
#         67.0                   1
#         67.5                   1
#         67.6                   1
#         68.7                   1
# Name: count, Length: 673, dtype: int64

# %%
df.groupby('gender')['age'].agg(lambda x: x.mode().iloc[0])
# Out:
# gender
# Female    18
# Male      18
# Name: age, dtype: int64

# %%
df.groupby('gender')['pass_fail'].value_counts()
# Out:
# gender  pass_fail
# Female  Pass         57034
#         Fail         47041
# Male    Pass         52355
#         Fail         43570
# Name: count, dtype: int64

# %%
df.groupby('gender')['daily_study_hours'].value_counts().sort_index()
# Out:
# gender  daily_study_hours
# Female  2                    16972
#         3                    51667
#         4                    26929
#         5                     6533
#         6                     1501
#         7                      351
#         8                      122
# Male    2                    15670
#         3                    47382
#         4                    24892
#         5                     6120
#         6                     1398
#         7                      343
#         8                      120
# Name: count, dtype: int64

# %%
df.groupby(['daily_study_hours','attendance_rate%'])['pass_fail'].value_counts()
# Out:
# daily_study_hours  attendance_rate%  pass_fail
# 2                  59.7              Fail          1
#                    62.5              Fail          1
#                    64.4              Fail          1
#                    65.5              Fail          1
#                    66.2              Fail          1
#                                                   ..
# 8                  99.7              Pass          3
#                    99.8              Pass          1
#                    99.9              Pass          3
#                    100.0             Pass         84
#                                      Fail          2
# Name: count, Length: 2995, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   gender                    200000 non-null  object
#  1   age                       200000 non-null  int64
#  2   parental_education_level  200000 non-null  int64
#  3   family_income             200000 non-null  int64
#  4   daily_study_hours         200000 non-null  int64
#  5   attendance_rate%          200000 non-null  float64
#  6   sleep_hours               200000 non-null  int64
#  7   stress_level              200000 non-null  int64
#  8   motivation_score          200000 non-null  int64
#  9   private_tutoring          200000 non-null  bool
#  10  internet_quality          200000 non-null  int64
#  11  math_score                200000 non-null  int64
#  12  reading_score             200000 non-null  int64
# ...

# %%
df.head()
# Out:
#    gender  age  parental_education_level  family_income  daily_study_hours  \
# 0  Female   15                         2          45000                  2
# 1    Male   19                         2          15000                  2
# 2  Female   20                         5          55000                  4
# 3  Female   16                         5          65000                  4
# 4    Male   20                         4          35000                  4
#
#    attendance_rate%  sleep_hours  stress_level  motivation_score  \
# 0              91.6            8             6                16
# 1              76.0            6             5                58
# 2              89.4            8             6                51
# 3              88.8            6             6                49
# 4              92.3            7             4                62
#
#    private_tutoring  internet_quality  math_score  reading_score  \
# ...

# %%
df['age'].value_counts()
# Out:
# age
# 18    46545
# 19    41094
# 17    37645
# 20    25554
# 16    21640
# 15    11410
# 21    11383
# 22     4729
# Name: count, dtype: int64

# %%
df.to_csv('cleaned_data.csv', index=False)
print('clenedfile_save_successfully')
# Out:
# clenedfile_save_successfully

# %%
#from google.colab import files

files.download('cleaned_data.csv')
